# %%
import numpy as np
import matplotlib.pyplot as plt
import math
        
DIAS_MES = 30
MESES = 12 # anio
CANT_MUESTRAS = 1

PRODUCCION = {
    'dias': 15,
    'auto_parte_1': 110,
    'auto_parte_2': 160    
}
DEMANDA = {
    'funcion': np.random.poisson,
    'parametros': {'lam': 70}    
}
EMPLEADOS = {
    'cantidad': 2,
    'horas_trabajo':12,  # ponemos que trabajan 12 horas diarias atendiendo demandas
    'funcion': np.random.poisson,
    'auto_parte_1': 8,
    'auto_parte_2': 12
}
cola_de_pedido = []


# En base a la cant de horas de trabajo y de la funcion de tiempo aleatorio de atencion de demanda:
# devuelvo la cantidad de demandas que puede procesra en un dia para auto parte 1 y autoparte 2.
def getCantDemandaEmpleado():
    total_minutos = EMPLEADOS['horas_trabajo'] * 60
    cant_demanda_1 = EMPLEADOS['funcion'](total_minutos/EMPLEADOS['auto_parte_1'])
    cant_demanda_2 = EMPLEADOS['funcion'](total_minutos/EMPLEADOS['auto_parte_2'])
    return cant_demanda_1, cant_demanda_2

# retorno una lista L con cant de demandas para cada empleado. len(L) == cantidad de empleados
def getCantDemandasEmpleados():
    cant_demandas_atender = []
    return [min(getCantDemandaEmpleado()) for i in range(EMPLEADOS['cantidad'])]

def main():    
    for i in range(CANT_MUESTRAS):
        cola_de_pedidos = [{'dia':0, 'mes':1, 'acumulado':0}]
        stock_autoparte_1 = stock_autoparte_2 =  0
        for mes in range(1, MESES + 1):
            for dia in range(1, DIAS_MES + 1 ):
                if dia < PRODUCCION['dias']:
                    stock_autoparte_1 += PRODUCCION['auto_parte_1']        
                    stock_autoparte_2 += PRODUCCION['auto_parte_2']
                cant_acumulada = cola_de_pedidos[len(cola_de_pedidos) - 1]['acumulado']
                demanda_aleatoria = DEMANDA['funcion'](**DEMANDA['parametros'])
                total_demanda_diaria = demanda_aleatoria + cant_acumulada
                cant_demandas_empleados = sum(getCantDemandasEmpleados())
                cant_demandas_satisfechas = min(stock_autoparte_1, stock_autoparte_2, total_demanda_diaria, cant_demandas_empleados)
                stock_autoparte_1 -= cant_demandas_satisfechas
                stock_autoparte_2 -= cant_demandas_satisfechas
                total_demanda_diaria -= cant_demandas_satisfechas
                cola_de_pedidos.append({'dia': dia, 
                                        'mes': mes, 
                                        'acumulado': total_demanda_diaria,
                                        'stock_autoparte_1':stock_autoparte_1,
                                        'stock_autoparte_2':stock_autoparte_2
                                       })
        for cola in cola_de_pedidos: print cola
        mostrar_promedios(cola_de_pedidos[1:])
        
def mostrar_promedios(cola_de_pedidos):
    print "/////// INICIO SIMULACION ///////"
    print "Cantidad total de dias %d"%(len(cola_de_pedidos))
    print "Cantidad total acumulada %d"%(sum(map( lambda dia: dia['acumulado'],cola_de_pedidos)))
    print "Promedio acumulado por dia %d"%(np.average(map(lambda dia: dia['acumulado'],cola_de_pedidos)))
    print "Cantidad de de dias con Demoras por empleados %d"%(len(demoras_empleados(cola_de_pedidos)))
    print "Cantidades demandas sin atender por demoras de empleados %s"%(sum(demoras_empleados(cola_de_pedidos)))
    
def demoras_empleados(cola_de_pedidos):
    return [res for res in map(demora_empleados_en, cola_de_pedidos) if res > 0]

#retorno cantidad de demandas insatisfechas en un dia por demoras de empleados.
def demora_empleados_en(dia):
    return min(min(dia['stock_autoparte_1'], dia['stock_autoparte_2']), dia['acumulado'])   
    
if __name__ == '__main__':
    main()
# Out:
# {'acumulado': 0, 'dia': 0, 'mes': 1}
# {'stock_autoparte_2': 92, 'acumulado': 0, 'dia': 1, 'mes': 1, 'stock_autoparte_1': 42}
# {'stock_autoparte_2': 167, 'acumulado': 0, 'dia': 2, 'mes': 1, 'stock_autoparte_1': 67}
# {'stock_autoparte_2': 251, 'acumulado': 0, 'dia': 3, 'mes': 1, 'stock_autoparte_1': 101}
# {'stock_autoparte_2': 339, 'acumulado': 0, 'dia': 4, 'mes': 1, 'stock_autoparte_1': 139}
# {'stock_autoparte_2': 429, 'acumulado': 0, 'dia': 5, 'mes': 1, 'stock_autoparte_1': 179}
# {'stock_autoparte_2': 521, 'acumulado': 0, 'dia': 6, 'mes': 1, 'stock_autoparte_1': 221}
# {'stock_autoparte_2': 607, 'acumulado': 0, 'dia': 7, 'mes': 1, 'stock_autoparte_1': 257}
# {'stock_autoparte_2': 696, 'acumulado': 0, 'dia': 8, 'mes': 1, 'stock_autoparte_1': 296}
# {'stock_autoparte_2': 787, 'acumulado': 0, 'dia': 9, 'mes': 1, 'stock_autoparte_1': 337}
# {'stock_autoparte_2': 867, 'acumulado': 0, 'dia': 10, 'mes': 1, 'stock_autoparte_1': 367}
# {'stock_autoparte_2': 963, 'acumulado': 0, 'dia': 11, 'mes': 1, 'stock_autoparte_1': 413}
# {'stock_autoparte_2': 1043, 'acumulado': 0, 'dia': 12, 'mes': 1, 'stock_autoparte_1': 443}
# {'stock_autoparte_2': 1133, 'acumulado': 0, 'dia': 13, 'mes': 1, 'stock_autoparte_1': 483}
# {'stock_autoparte_2': 1221, 'acumulado': 0, 'dia': 14, 'mes': 1, 'stock_autoparte_1': 521}
# {'stock_autoparte_2': 1150, 'acumulado': 0, 'dia': 15, 'mes': 1, 'stock_autoparte_1': 450}
# {'stock_autoparte_2': 1093, 'acumulado': 0, 'dia': 16, 'mes': 1, 'stock_autoparte_1': 393}
# {'stock_autoparte_2': 1032, 'acumulado': 0, 'dia': 17, 'mes': 1, 'stock_autoparte_1': 332}
# {'stock_autoparte_2': 962, 'acumulado': 0, 'dia': 18, 'mes': 1, 'stock_autoparte_1': 262}
# {'stock_autoparte_2': 878, 'acumulado': 0, 'dia': 19, 'mes': 1, 'stock_autoparte_1': 178}
# {'stock_autoparte_2': 805, 'acumulado': 0, 'dia': 20, 'mes': 1, 'stock_autoparte_1': 105}
# {'stock_autoparte_2': 735, 'acumulado': 0, 'dia': 21, 'mes': 1, 'stock_autoparte_1': 35}
# {'stock_autoparte_2': 700, 'acumulado': 43, 'dia': 22, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 117, 'dia': 23, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 197, 'dia': 24, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 265, 'dia': 25, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 341, 'dia': 26, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 404, 'dia': 27, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 472, 'dia': 28, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 543, 'dia': 29, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 700, 'acumulado': 604, 'dia': 30, 'mes': 1, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 750, 'acumulado': 574, 'dia': 1, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 800, 'acumulado': 534, 'dia': 2, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 856, 'acumulado': 486, 'dia': 3, 'mes': 2, 'stock_autoparte_1': 6}
# {'stock_autoparte_2': 903, 'acumulado': 440, 'dia': 4, 'mes': 2, 'stock_autoparte_1': 3}
# {'stock_autoparte_2': 950, 'acumulado': 401, 'dia': 5, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1000, 'acumulado': 359, 'dia': 6, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1050, 'acumulado': 313, 'dia': 7, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1100, 'acumulado': 276, 'dia': 8, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1150, 'acumulado': 229, 'dia': 9, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1200, 'acumulado': 184, 'dia': 10, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1252, 'acumulado': 126, 'dia': 11, 'mes': 2, 'stock_autoparte_1': 2}
# {'stock_autoparte_2': 1300, 'acumulado': 87, 'dia': 12, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1350, 'acumulado': 44, 'dia': 13, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1408, 'acumulado': 19, 'dia': 14, 'mes': 2, 'stock_autoparte_1': 8}
# {'stock_autoparte_2': 1400, 'acumulado': 88, 'dia': 15, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 169, 'dia': 16, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 243, 'dia': 17, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 310, 'dia': 18, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 366, 'dia': 19, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 433, 'dia': 20, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 503, 'dia': 21, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 576, 'dia': 22, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 654, 'dia': 23, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 741, 'dia': 24, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 820, 'dia': 25, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 883, 'dia': 26, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 949, 'dia': 27, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 1034, 'dia': 28, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 1113, 'dia': 29, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1400, 'acumulado': 1170, 'dia': 30, 'mes': 2, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1452, 'acumulado': 1122, 'dia': 1, 'mes': 3, 'stock_autoparte_1': 2}
# {'stock_autoparte_2': 1504, 'acumulado': 1091, 'dia': 2, 'mes': 3, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 1550, 'acumulado': 1040, 'dia': 3, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1600, 'acumulado': 990, 'dia': 4, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1650, 'acumulado': 974, 'dia': 5, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1700, 'acumulado': 931, 'dia': 6, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1751, 'acumulado': 894, 'dia': 7, 'mes': 3, 'stock_autoparte_1': 1}
# {'stock_autoparte_2': 1800, 'acumulado': 860, 'dia': 8, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1850, 'acumulado': 802, 'dia': 9, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1900, 'acumulado': 765, 'dia': 10, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 1950, 'acumulado': 720, 'dia': 11, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2000, 'acumulado': 678, 'dia': 12, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2052, 'acumulado': 628, 'dia': 13, 'mes': 3, 'stock_autoparte_1': 2}
# {'stock_autoparte_2': 2100, 'acumulado': 586, 'dia': 14, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 639, 'dia': 15, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 709, 'dia': 16, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 786, 'dia': 17, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 844, 'dia': 18, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 921, 'dia': 19, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 993, 'dia': 20, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1063, 'dia': 21, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1129, 'dia': 22, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1204, 'dia': 23, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1277, 'dia': 24, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1356, 'dia': 25, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1429, 'dia': 26, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1512, 'dia': 27, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1599, 'dia': 28, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1660, 'dia': 29, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2100, 'acumulado': 1733, 'dia': 30, 'mes': 3, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2150, 'acumulado': 1681, 'dia': 1, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2200, 'acumulado': 1656, 'dia': 2, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2250, 'acumulado': 1608, 'dia': 3, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2300, 'acumulado': 1558, 'dia': 4, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2350, 'acumulado': 1509, 'dia': 5, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2401, 'acumulado': 1482, 'dia': 6, 'mes': 4, 'stock_autoparte_1': 1}
# {'stock_autoparte_2': 2450, 'acumulado': 1441, 'dia': 7, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2500, 'acumulado': 1399, 'dia': 8, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2550, 'acumulado': 1364, 'dia': 9, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2600, 'acumulado': 1328, 'dia': 10, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2650, 'acumulado': 1287, 'dia': 11, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2700, 'acumulado': 1238, 'dia': 12, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2750, 'acumulado': 1204, 'dia': 13, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1148, 'dia': 14, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1216, 'dia': 15, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1293, 'dia': 16, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1368, 'dia': 17, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1447, 'dia': 18, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1518, 'dia': 19, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1583, 'dia': 20, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1643, 'dia': 21, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1715, 'dia': 22, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1792, 'dia': 23, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1864, 'dia': 24, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1923, 'dia': 25, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 1993, 'dia': 26, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 2047, 'dia': 27, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 2128, 'dia': 28, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 2191, 'dia': 29, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2800, 'acumulado': 2268, 'dia': 30, 'mes': 4, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2850, 'acumulado': 2236, 'dia': 1, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2900, 'acumulado': 2195, 'dia': 2, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 2950, 'acumulado': 2148, 'dia': 3, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3008, 'acumulado': 2130, 'dia': 4, 'mes': 5, 'stock_autoparte_1': 8}
# {'stock_autoparte_2': 3050, 'acumulado': 2067, 'dia': 5, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3100, 'acumulado': 2022, 'dia': 6, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3150, 'acumulado': 1975, 'dia': 7, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3200, 'acumulado': 1933, 'dia': 8, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3250, 'acumulado': 1887, 'dia': 9, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3305, 'acumulado': 1846, 'dia': 10, 'mes': 5, 'stock_autoparte_1': 5}
# {'stock_autoparte_2': 3352, 'acumulado': 1813, 'dia': 11, 'mes': 5, 'stock_autoparte_1': 2}
# {'stock_autoparte_2': 3407, 'acumulado': 1790, 'dia': 12, 'mes': 5, 'stock_autoparte_1': 7}
# {'stock_autoparte_2': 3454, 'acumulado': 1736, 'dia': 13, 'mes': 5, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 3500, 'acumulado': 1696, 'dia': 14, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 1770, 'dia': 15, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 1835, 'dia': 16, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 1903, 'dia': 17, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 1971, 'dia': 18, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2046, 'dia': 19, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2121, 'dia': 20, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2193, 'dia': 21, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2266, 'dia': 22, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2337, 'dia': 23, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2397, 'dia': 24, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2466, 'dia': 25, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2547, 'dia': 26, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2605, 'dia': 27, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2677, 'dia': 28, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2744, 'dia': 29, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3500, 'acumulado': 2789, 'dia': 30, 'mes': 5, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3550, 'acumulado': 2740, 'dia': 1, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3600, 'acumulado': 2686, 'dia': 2, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3654, 'acumulado': 2643, 'dia': 3, 'mes': 6, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 3700, 'acumulado': 2586, 'dia': 4, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3750, 'acumulado': 2551, 'dia': 5, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3800, 'acumulado': 2517, 'dia': 6, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3850, 'acumulado': 2471, 'dia': 7, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3900, 'acumulado': 2412, 'dia': 8, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 3950, 'acumulado': 2372, 'dia': 9, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4000, 'acumulado': 2334, 'dia': 10, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4051, 'acumulado': 2292, 'dia': 11, 'mes': 6, 'stock_autoparte_1': 1}
# {'stock_autoparte_2': 4100, 'acumulado': 2230, 'dia': 12, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4150, 'acumulado': 2184, 'dia': 13, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2137, 'dia': 14, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2206, 'dia': 15, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2287, 'dia': 16, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2358, 'dia': 17, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2420, 'dia': 18, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2488, 'dia': 19, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2556, 'dia': 20, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2616, 'dia': 21, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2700, 'dia': 22, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2782, 'dia': 23, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2862, 'dia': 24, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2925, 'dia': 25, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 2983, 'dia': 26, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 3048, 'dia': 27, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 3108, 'dia': 28, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 3181, 'dia': 29, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4200, 'acumulado': 3242, 'dia': 30, 'mes': 6, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4250, 'acumulado': 3207, 'dia': 1, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4302, 'acumulado': 3180, 'dia': 2, 'mes': 7, 'stock_autoparte_1': 2}
# {'stock_autoparte_2': 4350, 'acumulado': 3148, 'dia': 3, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4400, 'acumulado': 3093, 'dia': 4, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4450, 'acumulado': 3065, 'dia': 5, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4500, 'acumulado': 3012, 'dia': 6, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4552, 'acumulado': 2971, 'dia': 7, 'mes': 7, 'stock_autoparte_1': 2}
# {'stock_autoparte_2': 4600, 'acumulado': 2925, 'dia': 8, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4650, 'acumulado': 2889, 'dia': 9, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4703, 'acumulado': 2859, 'dia': 10, 'mes': 7, 'stock_autoparte_1': 3}
# {'stock_autoparte_2': 4750, 'acumulado': 2820, 'dia': 11, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4804, 'acumulado': 2782, 'dia': 12, 'mes': 7, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 4863, 'acumulado': 2758, 'dia': 13, 'mes': 7, 'stock_autoparte_1': 13}
# {'stock_autoparte_2': 4901, 'acumulado': 2705, 'dia': 14, 'mes': 7, 'stock_autoparte_1': 1}
# {'stock_autoparte_2': 4900, 'acumulado': 2774, 'dia': 15, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 2848, 'dia': 16, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 2913, 'dia': 17, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 2985, 'dia': 18, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3048, 'dia': 19, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3112, 'dia': 20, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3157, 'dia': 21, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3221, 'dia': 22, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3306, 'dia': 23, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3369, 'dia': 24, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3457, 'dia': 25, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3527, 'dia': 26, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3608, 'dia': 27, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3687, 'dia': 28, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3759, 'dia': 29, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4900, 'acumulado': 3829, 'dia': 30, 'mes': 7, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 4950, 'acumulado': 3773, 'dia': 1, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5000, 'acumulado': 3731, 'dia': 2, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5050, 'acumulado': 3698, 'dia': 3, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5108, 'acumulado': 3674, 'dia': 4, 'mes': 8, 'stock_autoparte_1': 8}
# {'stock_autoparte_2': 5151, 'acumulado': 3623, 'dia': 5, 'mes': 8, 'stock_autoparte_1': 1}
# {'stock_autoparte_2': 5200, 'acumulado': 3567, 'dia': 6, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5260, 'acumulado': 3545, 'dia': 7, 'mes': 8, 'stock_autoparte_1': 10}
# {'stock_autoparte_2': 5300, 'acumulado': 3489, 'dia': 8, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5350, 'acumulado': 3444, 'dia': 9, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5400, 'acumulado': 3407, 'dia': 10, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5450, 'acumulado': 3366, 'dia': 11, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5500, 'acumulado': 3327, 'dia': 12, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5554, 'acumulado': 3292, 'dia': 13, 'mes': 8, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 5600, 'acumulado': 3251, 'dia': 14, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3322, 'dia': 15, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3408, 'dia': 16, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3490, 'dia': 17, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3581, 'dia': 18, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3665, 'dia': 19, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3730, 'dia': 20, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3798, 'dia': 21, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3874, 'dia': 22, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 3936, 'dia': 23, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4010, 'dia': 24, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4077, 'dia': 25, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4142, 'dia': 26, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4199, 'dia': 27, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4275, 'dia': 28, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4341, 'dia': 29, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5600, 'acumulado': 4406, 'dia': 30, 'mes': 8, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5650, 'acumulado': 4360, 'dia': 1, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5700, 'acumulado': 4322, 'dia': 2, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5755, 'acumulado': 4279, 'dia': 3, 'mes': 9, 'stock_autoparte_1': 5}
# {'stock_autoparte_2': 5803, 'acumulado': 4240, 'dia': 4, 'mes': 9, 'stock_autoparte_1': 3}
# {'stock_autoparte_2': 5850, 'acumulado': 4186, 'dia': 5, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5900, 'acumulado': 4139, 'dia': 6, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 5961, 'acumulado': 4113, 'dia': 7, 'mes': 9, 'stock_autoparte_1': 11}
# {'stock_autoparte_2': 6007, 'acumulado': 4062, 'dia': 8, 'mes': 9, 'stock_autoparte_1': 7}
# {'stock_autoparte_2': 6050, 'acumulado': 4020, 'dia': 9, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6100, 'acumulado': 3963, 'dia': 10, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6150, 'acumulado': 3928, 'dia': 11, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6200, 'acumulado': 3896, 'dia': 12, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6250, 'acumulado': 3853, 'dia': 13, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 3803, 'dia': 14, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 3880, 'dia': 15, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 3957, 'dia': 16, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4020, 'dia': 17, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4085, 'dia': 18, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4147, 'dia': 19, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4235, 'dia': 20, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4282, 'dia': 21, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4352, 'dia': 22, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4424, 'dia': 23, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4483, 'dia': 24, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4544, 'dia': 25, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4607, 'dia': 26, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4679, 'dia': 27, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4758, 'dia': 28, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4822, 'dia': 29, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6300, 'acumulado': 4885, 'dia': 30, 'mes': 9, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6350, 'acumulado': 4839, 'dia': 1, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6400, 'acumulado': 4803, 'dia': 2, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6450, 'acumulado': 4758, 'dia': 3, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6500, 'acumulado': 4713, 'dia': 4, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6550, 'acumulado': 4671, 'dia': 5, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6600, 'acumulado': 4649, 'dia': 6, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6650, 'acumulado': 4594, 'dia': 7, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6700, 'acumulado': 4555, 'dia': 8, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6750, 'acumulado': 4527, 'dia': 9, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6806, 'acumulado': 4502, 'dia': 10, 'mes': 10, 'stock_autoparte_1': 6}
# {'stock_autoparte_2': 6872, 'acumulado': 4472, 'dia': 11, 'mes': 10, 'stock_autoparte_1': 22}
# {'stock_autoparte_2': 6900, 'acumulado': 4416, 'dia': 12, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 6950, 'acumulado': 4378, 'dia': 13, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4322, 'dia': 14, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4387, 'dia': 15, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4471, 'dia': 16, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4534, 'dia': 17, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4599, 'dia': 18, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4674, 'dia': 19, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4760, 'dia': 20, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4822, 'dia': 21, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4872, 'dia': 22, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4932, 'dia': 23, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 4994, 'dia': 24, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 5057, 'dia': 25, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 5123, 'dia': 26, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 5183, 'dia': 27, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 5257, 'dia': 28, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 5345, 'dia': 29, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7000, 'acumulado': 5410, 'dia': 30, 'mes': 10, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7061, 'acumulado': 5387, 'dia': 1, 'mes': 11, 'stock_autoparte_1': 11}
# {'stock_autoparte_2': 7101, 'acumulado': 5342, 'dia': 2, 'mes': 11, 'stock_autoparte_1': 1}
# {'stock_autoparte_2': 7150, 'acumulado': 5293, 'dia': 3, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7200, 'acumulado': 5242, 'dia': 4, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7250, 'acumulado': 5198, 'dia': 5, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7312, 'acumulado': 5168, 'dia': 6, 'mes': 11, 'stock_autoparte_1': 12}
# {'stock_autoparte_2': 7355, 'acumulado': 5123, 'dia': 7, 'mes': 11, 'stock_autoparte_1': 5}
# {'stock_autoparte_2': 7411, 'acumulado': 5090, 'dia': 8, 'mes': 11, 'stock_autoparte_1': 11}
# {'stock_autoparte_2': 7456, 'acumulado': 5028, 'dia': 9, 'mes': 11, 'stock_autoparte_1': 6}
# {'stock_autoparte_2': 7504, 'acumulado': 4993, 'dia': 10, 'mes': 11, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 7550, 'acumulado': 4937, 'dia': 11, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7600, 'acumulado': 4895, 'dia': 12, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7650, 'acumulado': 4865, 'dia': 13, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7710, 'acumulado': 4825, 'dia': 14, 'mes': 11, 'stock_autoparte_1': 10}
# {'stock_autoparte_2': 7700, 'acumulado': 4875, 'dia': 15, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 4952, 'dia': 16, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5016, 'dia': 17, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5085, 'dia': 18, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5142, 'dia': 19, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5208, 'dia': 20, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5283, 'dia': 21, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5345, 'dia': 22, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5415, 'dia': 23, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5497, 'dia': 24, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5553, 'dia': 25, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5622, 'dia': 26, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5683, 'dia': 27, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5762, 'dia': 28, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5818, 'dia': 29, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7700, 'acumulado': 5887, 'dia': 30, 'mes': 11, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 7754, 'acumulado': 5867, 'dia': 1, 'mes': 12, 'stock_autoparte_1': 4}
# {'stock_autoparte_2': 7808, 'acumulado': 5831, 'dia': 2, 'mes': 12, 'stock_autoparte_1': 8}
# {'stock_autoparte_2': 7867, 'acumulado': 5809, 'dia': 3, 'mes': 12, 'stock_autoparte_1': 17}
# {'stock_autoparte_2': 7923, 'acumulado': 5784, 'dia': 4, 'mes': 12, 'stock_autoparte_1': 23}
# {'stock_autoparte_2': 7970, 'acumulado': 5741, 'dia': 5, 'mes': 12, 'stock_autoparte_1': 20}
# {'stock_autoparte_2': 8019, 'acumulado': 5701, 'dia': 6, 'mes': 12, 'stock_autoparte_1': 19}
# {'stock_autoparte_2': 8058, 'acumulado': 5653, 'dia': 7, 'mes': 12, 'stock_autoparte_1': 8}
# {'stock_autoparte_2': 8118, 'acumulado': 5622, 'dia': 8, 'mes': 12, 'stock_autoparte_1': 18}
# {'stock_autoparte_2': 8160, 'acumulado': 5562, 'dia': 9, 'mes': 12, 'stock_autoparte_1': 10}
# {'stock_autoparte_2': 8213, 'acumulado': 5515, 'dia': 10, 'mes': 12, 'stock_autoparte_1': 13}
# {'stock_autoparte_2': 8272, 'acumulado': 5483, 'dia': 11, 'mes': 12, 'stock_autoparte_1': 22}
# {'stock_autoparte_2': 8311, 'acumulado': 5432, 'dia': 12, 'mes': 12, 'stock_autoparte_1': 11}
# {'stock_autoparte_2': 8350, 'acumulado': 5379, 'dia': 13, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5344, 'dia': 14, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5423, 'dia': 15, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5489, 'dia': 16, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5557, 'dia': 17, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5633, 'dia': 18, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5717, 'dia': 19, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5790, 'dia': 20, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5858, 'dia': 21, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5929, 'dia': 22, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 5990, 'dia': 23, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6059, 'dia': 24, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6126, 'dia': 25, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6202, 'dia': 26, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6279, 'dia': 27, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6359, 'dia': 28, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6413, 'dia': 29, 'mes': 12, 'stock_autoparte_1': 0}
# {'stock_autoparte_2': 8400, 'acumulado': 6479, 'dia': 30, 'mes': 12, 'stock_autoparte_1': 0}
# /////// INICIO SIMULACION ///////
# Cantidad total de dias 360
# Cantidad total acumulada 1044948
# Promedio acumulado por dia 2902
# Cantidad de de dias con Demoras por empleados 52
# Cantidades demandas sin atender por demoras de empleados 395
